# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoramires/RepositorioAulaGit/blob/dev/Notebook_aula_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/leonardoramires/RepositorioAulaGit/dev/Dados/ExercicioAula.csv'

# %%
df = pd.read_csv(url, sep=';')
df
# Out:
#                          Nome da pessoa  Idade da pessoa   Documento CPF  \
# 0              Marli Juliana Nascimento               67  147.676.158-28
# 1         Gabriela Alana Mariah Drumond               78  909.394.958-64
# 2                  Cauã Renato Silveira               19  796.865.138-76
# 3     Benedito Sérgio Sebastião Cardoso               40  748.225.288-63
# 4          Flávia Isadora Lívia Moreira               20  568.818.498-18
# ...                                 ...              ...             ...
# 1595                Gustavo Luís Fogaça               22  431.259.578-00
# 1596      Sebastião Noah Anthony Castro               34  316.256.308-91
# 1597                     Enzo Ruan Dias               42  440.535.058-28
# 1598           Francisco Isaac Carvalho               57  604.360.418-39
# 1599       Elias Caleb Leonardo da Mata               68  917.381.098-36
#
#      Data de Nascimento Sexo da pessoa Signo da Pessoa  \
# ...
